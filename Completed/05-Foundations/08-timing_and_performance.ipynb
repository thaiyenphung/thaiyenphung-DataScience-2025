# %% [markdown]
# <a href="https://colab.research.google.com/github/thaiyenphung/thaiyenphung-DataScience-2025/blob/main/Completed/05-Foundations/08-timing_and_performance.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ⏱️ 08 - Timing and Performance
#
# In data science, performance matters. Some code runs fast, some slow.
# Jupyter/IPython gives us tools to measure runtime easily.
#
# In this notebook you will learn:
# - `%time` and `%timeit` for single expressions
# - `%%time` and `%%timeit` for entire cells
# - Comparing loops, list comprehensions, and NumPy
# - Why performance awareness is important

# %% [markdown]
# ## 1. `%time`

# %%
# %time sum(range(1_000_000))
# Out:
# CPU times: user 12.2 ms, sys: 26 µs, total: 12.2 ms
# Wall time: 12.1 ms
# 499999500000

# %% [markdown]
# ✅ **Your Turn**: Use `%time` to measure how long it takes to sort a list of 1 million random numbers.

# %%
import numpy as np

# Create a list of 1 million random numbers
nums = np.random.rand(1000000).tolist()

# %time nums.sort()
# Out:
# CPU times: user 287 ms, sys: 0 ns, total: 287 ms
# Wall time: 287 ms

# %% [markdown]
# ## 2. `%timeit`

# %%
numbers = list(range(1_000))
# %timeit [x**2 for x in numbers]
# Out:
# 33 µs ± 463 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Compare `%timeit` results for a list comprehension vs. a `for` loop that builds the same list.

# %%
# List comprehension
nums = list(range(1000))
# %timeit [x**3 for x in nums]

# For loop
# %timeit nums = []; [nums.append(x**3) for x in range(1000)]
# Out:
# 47.2 µs ± 466 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 78 µs ± 13.6 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %% [markdown]
# ## 3. `%%time` for a Whole Cell

# %%
# %%timeit
total = 0
for i in range(1_000_000):
    total += i
total
# Out:
# 20.2 ms ± 765 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# ✅ **Your Turn**: Wrap a longer multi-line operation with `%%time` to measure its runtime.

# %%
# %%time
nums = []
for x in range(1000):
    nums.append(x**3)
# Out:
# CPU times: user 135 µs, sys: 2 µs, total: 137 µs
# Wall time: 139 µs

# %% [markdown]
# ## 4. Comparing Loops vs. NumPy

# %%
import numpy as np

numbers = np.arange(1_000_000)

# Python loop
# %timeit [x**2 for x in numbers]

# NumPy vectorized
# %timeit numbers**2
# Out:
# 113 ms ± 18.1 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)
# 382 µs ± 30.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %% [markdown]
# ✅ **Your Turn**: Try squaring numbers with a Python loop, list comprehension, and NumPy array. Compare times.

# %%
import numpy as np

numbers = np.arange(1000)
listNums = list(range(1000))

# Python loop
# %timeit [x**2 for x in numbers]

# List comprehension
# %timeit [x**2 for x in listNums]

# NumPy vectorized
# %timeit numbers**2
# Out:
# 92.6 µs ± 16.1 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 33.6 µs ± 512 ns per loop (mean ± std. dev. of 7 runs, 10000 loops each)
# 1.03 µs ± 212 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %% [markdown]
# ## 5. Why This Matters
# - Performance differences become huge with large datasets.
# - Vectorized operations (like NumPy, Pandas) are usually faster.
# - `%timeit` is your friend when deciding how to implement something.

# %% [markdown]
# ---
# ### Summary
# - `%time` and `%timeit` measure execution speed.
# - `%%time` and `%%timeit` work on whole cells.
# - Loops are slower than list comprehensions, which are slower than NumPy.
# - Always measure performance before optimizing.
