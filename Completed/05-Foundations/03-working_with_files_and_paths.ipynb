# %% [markdown]
# <a href="https://colab.research.google.com/github/thaiyenphung/thaiyenphung-DataScience-2025/blob/main/Completed/05-Foundations/03-working_with_files_and_paths.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📂 03 - Working with Files and Paths
#
# Data science means working with files all the time: datasets, config files, logs.
# This notebook introduces:
# - Checking your current path in Jupyter
# - Navigating directories
# - Reading and writing text files
# - Using `with` for safe file handling
# - Basics of JSON and CSV I/O

# %% [markdown]
# ## 1. Where Am I?

# %%
# %pwd  # Print current working directory
# Out:
# '/content'

# %%
# %ls  # List files in the current directory
# Out:
# sample_data/

# %%
# %cd ..  # Change to parent directory
# %pwd
# Out:
# [Errno 2] No such file or directory: '.. # Change to parent directory'
# /content
# '/content'

# %% [markdown]
# ✅ **Your Turn**: Navigate into a subfolder of your repo (e.g., `Foundations/`) and list its contents.

# %%
# !git clone https://github.com/thaiyenphung/thaiyenphung-DataScience-2025.git

# %cd thaiyenphung-DataScience-2025/Completed

# %ls
# Out:
# Cloning into 'thaiyenphung-DataScience-2025'...
# remote: Enumerating objects: 247, done.
# remote: Counting objects: 100% (247/247), done.
# remote: Compressing objects: 100% (213/213), done.
# remote: Total 247 (delta 101), reused 94 (delta 18), pack-reused 0 (from 0)
# Receiving objects: 100% (247/247), 4.98 MiB | 12.71 MiB/s, done.
# Resolving deltas: 100% (101/101), done.
# /content/thaiyenphung-DataScience-2025/Completed
# 00-StartHere/        02-Working_with_Data/              04-Loops_and_Iteration/
# 01-Getting_Started/  03-Scalar_Types_and_Control_Flow/  05-Foundations/

# %%
# %cd 02-Working_with_Data/

# %ls
# Out:
# /content/thaiyenphung-DataScience-2025/Completed/02-Working_with_Data
# 01-Lists.ipynb   03-Data_Types_and_Arithmetic.ipynb  mini-quiz.md
# 02-Tuples.ipynb  03-Dictionaries.ipynb

# %% [markdown]
# ## 2. Writing and Reading Text Files

# %%
# Writing to a text file
with open("example.txt", "w") as f:
    f.write("Hello, Jupyter!\n")
    f.write("This is a text file.\n")

# %%
# Reading from a text file
with open("example.txt", "r") as f:
    contents = f.read()
contents
# Out:
# 'Hello, Jupyter!\nThis is a text file.\n'

# %% [markdown]
# ✅ **Your Turn**: Write your name into a file called `me.txt`, then read it back and print the result.

# %%
# Writing to a text file
with open("me.txt", "w") as f:
    f.write("Phung Thai")

# Reading from a text file
with open("me.txt", "r") as f:
    contents = f.read()

# Print the content in the text file
contents
# Out:
# 'Phung Thai'

# %% [markdown]
# ## 3. JSON Files

# %%
import json

data = {"name": "Graylian", "type": "mascot", "skills": ["howl", "parrot talk"]}

# Write JSON
with open("data.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("data.json", "r") as f:
    loaded = json.load(f)
loaded
# Out:
# {'name': 'Graylian', 'type': 'mascot', 'skills': ['howl', 'parrot talk']}

# %% [markdown]
# ✅ **Your Turn**: Create a dictionary with your name and 2-3 favorite courses. Save it to `courses.json`, then read it back.

# %%
import json

# Create a dictionary
data = {"name": "Phung Thai",
        "favorite courses": ["Intro to Computer Architecture",
                             "Calculus",
                             "Data Structures and ADT"]}

# Write JSON
with open("courses.json", "w") as f:
    json.dump(data, f)

# Read JSON
with open("courses.json", "r") as f:
    loaded = json.load(f)

# Display dictionary
loaded
# Out:
# {'name': 'Phung Thai',
#  'favorite courses': ['Intro to Computer Architecture',
#   'Calculus',
#   'Data Structures and ADT']}

# %% [markdown]
# ## 4. CSV Files

# %%
import csv

# Writing CSV
rows = [["Name", "Score"], ["Alice", 90], ["Bob", 85]]
with open("scores.csv", "w", newline="") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CSV
with open("scores.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Score']
# ['Alice', '90']
# ['Bob', '85']

# %% [markdown]
# ✅ **Your Turn**: Create a CSV with 3 rows of your own data (e.g., pets, grades, or hobbies). Read it back and display the rows.

# %%
import csv

#Writing CSV
rows = [["Movie Name", "Genre", "Release Year"],
        ["Inception", "Science Fiction", 2010],
        ["Forrest Gump", "Drama", 1994],
        ["Spirited Away", "Animation", 2001]]

with open("movies.csv", "w", newline = "") as f:
    writer = csv.writer(f)
    writer.writerows(rows)

# Reading CVS
with open("movies.csv", "r") as f:
    reader = csv.reader(f)
    for row in reader:
        print(row)
# Out:
# ['Movie Name', 'Genre', 'Release Year']
# ['Inception', 'Science Fiction', '2010']
# ['Forrest Gump', 'Drama', '1994']
# ['Spirited Away', 'Animation', '2001']

# %% [markdown]
# ---
# ### Summary
# - `%pwd`, `%ls`, `%cd` show you where you are in the filesystem.
# - Use `with open(...)` to safely read/write files.
# - JSON is for structured data (key/value).
# - CSV is for tabular data (rows/columns).
# - Managing files is step 1 in any real data science project.
