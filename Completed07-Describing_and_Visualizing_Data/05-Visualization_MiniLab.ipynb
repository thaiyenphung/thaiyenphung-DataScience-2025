# %% [markdown]
# <a href="https://colab.research.google.com/github/thaiyenphung/thaiyenphung-DataScience-2025/blob/main/Completed07-Describing_and_Visualizing_Data/05-Visualization_MiniLab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 🔬 Visualization Mini-Lab: Trends and Outliers
#
# Now it’s time to put your skills to the test!
# In this mini-lab, you’ll explore a real dataset, create visualizations, and identify **trends and outliers**.
#
# We’ll use the famous **Penguins dataset** (thanks to Seaborn).

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# Load dataset
penguins = sns.load_dataset("penguins")
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female

# %% [markdown]
# ## 1. Explore Distributions
#
# First, let’s look at the distribution of **body mass**.

# %%
sns.histplot(data=penguins, x="body_mass_g", kde=True, hue="species")
plt.title("Distribution of Body Mass by Species")
plt.show()

# %% [markdown]
# 👉 **Task:** Do some species have higher average body mass than others?

# %% [markdown]
# Yes, Gentoo penguins have the highest body mass.

# %% [markdown]
# ## 2. Relationships Between Variables
#
# Scatterplots help us see trends between two quantitative variables.

# %%
sns.scatterplot(data=penguins, x="flipper_length_mm", y="body_mass_g", hue="species")
plt.title("Flipper Length vs Body Mass")
plt.show()

# %% [markdown]
# 👉 **Task:** Which species tends to have longer flippers AND higher body mass?

# %% [markdown]
# Gentoo has both longer flippers and higher body mass.

# %% [markdown]
# ## 3. Box Plots for Outliers
#
# Box plots are great for spotting outliers.

# %%
sns.boxplot(data=penguins, x="species", y="bill_length_mm", palette="Set2")
plt.title("Bill Length by Species")
plt.show()
# Out:
# /tmp/ipython-input-722458408.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=penguins, x="species", y="bill_length_mm", palette="Set2")

# %% [markdown]
# 👉 **Task:** Can you spot any outliers in the bill length data?

# %% [markdown]
# Gentoo has an outlier with a bill length around 59-60 mm

# %% [markdown]
# ## 4. Correlation Heatmap
#
# Correlation heatmaps let us see overall variable relationships.

# %%
corr = penguins.dropna().corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", center=0)
plt.title("Correlation Heatmap")
plt.show()

# %% [markdown]
# 👉 **Task:** Which variables appear to be strongly correlated?

# %% [markdown]
# The strongest correlation is between flipper length and body mass.

# %% [markdown]
# ## 5. Your Turn
#
# - Try a different dataset (e.g., `tips`, `iris`).
# - Create **at least 2 plots** that reveal a trend.
# - Create **1 plot** that highlights possible outliers.
# - Write a short summary of your findings.
#
# > Remember: The goal is to **use visualizations to tell a story about the data.**

# %%
# Load iris dataset
iris = sns.load_dataset("iris")
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Create 2 plots that reveal a trend

# %% [markdown]
# 1. Plot 1

# %%
# Show a trend between sepal length and pedel width
sns.scatterplot(data=iris, x="sepal_length", y="petal_length", hue="species")
plt.title("Sepal Length vs Petal Length")
plt.show()

# %% [markdown]
# 2. Plot 2

# %%
# Show the distribution of petal length
sns.histplot(data=iris, x="petal_length", kde=True, hue="species")
plt.title("Distribution of Petal Length by Species")
plt.xlabel("Petal Length (cm)")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# ## Create 1 plot that highlights possible outliers.

# %%
sns.boxplot(data=iris, x="species", y="sepal_width", palette="coolwarm")
plt.title("Outliers in Sepal Width by Species")
plt.xlabel("Species")
plt.ylabel("Sepal Width (cm)")
plt.show()
# Out:
# /tmp/ipython-input-2314264392.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=iris, x="species", y="sepal_width", palette="coolwarm")

# %% [markdown]
# ## Summary of Findings
# - Sepal length and petal length are strongly related. Flowers with longer sepals tend to have longer petals.
# - The histogram of petal length shows distinct ranges for each species: setosa has short petals, virginica has the longest petals, and versicolor falls in the middle.
# - The boxplot of sepal width shows a few outliers, mainly in setos, suggesting more variation in that species.

# %% [markdown]
# ---
# ✅ Congratulations! You’ve completed the visualization mini-lab and Week 07.
#
# Next module → Working with larger datasets and diving deeper into analysis.
